# %%
#the project with  part 1 scale to be changed (w) and the pic dont be downsample and choose the the best one
#also count the corner to be sure
#part 2 the scale(w) don't change and the pic get downsample and select the best one and show it

# %%
#I counted the corners and it was 80 corners
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import numpy as np
I=cv2.imread("corner6.jpg")
g=cv2.imread("corner6.jpg",0)
cv2_imshow(g)
g=np.float32(g)
for k in range(1,7):
  win_size=2**k
  sobel_k_size=3
  alpha=0.04
  #g,win_size,sobel_k_size,alpha
  h=cv2.cornerHarris(g,win_size,sobel_k_size,alpha)
  h=h/h.max()
  c=np.uint8(h>0.01)*255
  nc,cc=cv2.connectedComponents(c);
  j=I.copy()
  j[c != 0] = [0,255,30]
  if nc-1==80:
   cv2.putText(j,'w=%d, c=%d' %(win_size,nc-1),(20,40),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
   cv2_imshow(j)
  else:
    print("the desired window",'w=%d, c=%d' %(win_size,nc-1) ,"didn't count the corners right")
# Out:
# <PIL.Image.Image image mode=L size=360x360>
# the desired window w=2, c=72 didn't count the corners right
# <PIL.Image.Image image mode=RGB size=360x360>
# the desired window w=8, c=32 didn't count the corners right
# the desired window w=16, c=12 didn't count the corners right
# the desired window w=32, c=2 didn't count the corners right
# the desired window w=64, c=1 didn't count the corners right

# %%
#part2
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import numpy as np
I=cv2.imread("corner6.jpg")
g=cv2.imread("corner6.jpg",0)
cv2_imshow(g)

psize=6
J=I.copy()
J=np.float32(J)
pyr=[J]
for k in range(1,7):
 for i in range(psize-1):
  J=cv2.pyrDown(J)
  pyr.append(J)
  cv2_imshow(J)
  win_size=2**k
  sobel_k_size=3
  alpha=0.04
  #g,win_size,sobel_k_size,alpha
  h=cv2.cornerHarris(g,win_size,sobel_k_size,alpha)
  h=h/h.max()
  c=np.uint8(h>0.01)*255
  nc,cc=cv2.connectedComponents(c);
  j=I.copy()
  j[c != 0] = [0,255,30]
  if nc-1==80:
   cv2.putText(j,'w=%d, c=%d psize=%d' %(win_size,nc-1,i),(20,40),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
   cv2_imshow(j)
  else:
    print("the desired window",'w=%d, c=%d psize=%d' %(win_size,nc-1,i) ,"didn't count the corners right")
# Out:
# <PIL.Image.Image image mode=L size=360x360>
# <PIL.Image.Image image mode=RGB size=180x180>
# the desired window w=2, c=72 psize=0 didn't count the corners right
# <PIL.Image.Image image mode=RGB size=90x90>
# the desired window w=2, c=72 psize=1 didn't count the corners right
# <PIL.Image.Image image mode=RGB size=45x45>
# the desired window w=2, c=72 psize=2 didn't count the corners right
# <PIL.Image.Image image mode=RGB size=23x23>
# the desired window w=2, c=72 psize=3 didn't count the corners right
# <PIL.Image.Image image mode=RGB size=12x12>
# the desired window w=2, c=72 psize=4 didn't count the corners right
# <PIL.Image.Image image mode=RGB size=6x6>
# <PIL.Image.Image image mode=RGB size=360x360>
# <PIL.Image.Image image mode=RGB size=3x3>
# <PIL.Image.Image image mode=RGB size=360x360>
# <PIL.Image.Image image mode=RGB size=2x2>
# <PIL.Image.Image image mode=RGB size=360x360>
# <PIL.Image.Image image mode=RGB size=1x1>
# <PIL.Image.Image image mode=RGB size=360x360>
# ...
